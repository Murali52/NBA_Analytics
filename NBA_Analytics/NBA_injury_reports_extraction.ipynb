# %% [markdown]
# ## NBA PLAYER INJURY OFFICIAL DAILY REPORT - DATA EXTRACTION MODULE
# ### This NBA Official Daily Player Injury Report Data Extraction (2023-24 and 2024-25 season)
# ### Every season seems to have different format esp. when we use table.extract() from the pdf document
# ### Injury Reports from NBA are typically in
# ### URL: https://ak-static.cms.nba.com/referee/injury/Injury-Report_{date_str}_10AM.pdf
# #### Authored by Murali Balasubramanian, DBA, Walsh College, MI, USA

# %% [markdown]
# ## This code below is only valid for 2024-25 NBA season
# ### Also beware the All-star break between 12-Feb to 18-Feb-25 has no bulletins, so API call will fail for this period

# %%
import pandas as pd
import requests
from io import BytesIO
import pdfplumber
from datetime import datetime, timedelta
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

def generate_injury_report_urls(start_date, end_date):
    """
    Generate URLs for injury reports between specified dates.
    
    Args:
        start_date (str): Start date in YYYY-MM-DD format
        end_date (str): End date in YYYY-MM-DD format
    
    Returns:
        list: List of URLs for injury reports
    """
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    urls = []
    while start <= end:
        date_str = start.strftime("%Y-%m-%d")
        url = f"https://ak-static.cms.nba.com/referee/injury/Injury-Report_{date_str}_10AM.pdf"
        urls.append(url)
        start += timedelta(days=1)
    return urls
    
def split_name(full_name):
    """
    Split a full name into last name and first name.
    Handles common name formats like "Last, First" and "First Last"
    """
    if not full_name:
        return ["", ""]
    
    # Handle "Last, First" format
    if ',' in full_name:
        parts = full_name.split(',')
        return [parts[0].strip(), parts[1].strip()]
    
    # Handle "First Last" format
    parts = full_name.split()
    if len(parts) >= 2:
        return [parts[-1], ' '.join(parts[:-1])]
    
    # If we can't split the name, return it as last name
    return [full_name, ""]
    
def parse_injury_pdf(pdf_url, game_date=None):
    try:
        print(f"Attempting to fetch: {pdf_url}")
        
        # Setup retry strategy for requests
        session = requests.Session()
        retry_strategy = Retry(
            total=3,
            backoff_factor=1,
            status_forcelist=[429, 500, 502, 503, 504]
        )
        adapter = HTTPAdapter(max_retries=retry_strategy)
        session.mount("http://", adapter)
        session.mount("https://", adapter)
        
        response = session.get(pdf_url, timeout=30)
        if response.status_code != 200:
            print(f"Failed to fetch: {pdf_url}") 
            return pd.DataFrame()
            
        with pdfplumber.open(BytesIO(response.content)) as pdf:
            data_list = []
            date_encountered = False
            date_row_data = None
            
            for page in pdf.pages:
                tables = page.find_tables({
                    "vertical_strategy": "explicit",
                    "horizontal_strategy": "explicit",
                    "explicit_vertical_lines": [edge["x0"] for edge in page.edges],
                    "explicit_horizontal_lines": [edge["top"] for edge in page.edges],
                    "snap_tolerance": 5,
                    "join_tolerance": 5
                })
                
               # print(f" Found {len(tables)} tables on page") # For debugging
                
                for table in tables:
                    table_data = table.extract()
                    # print(f"Table shape: {len(table_data)} rows") # For debugging
                    
                    for i, row in enumerate(table_data):
                        # print(f" Row {i} contents:") # For debugging
                        # print(f" Length: {len(row)}") # For debugging
                        # print(f" Row data: {row}") # For debugging
                        
                        # Skip empty rows
                        if not any(row):
                            print("  → Skipping empty row")
                            continue
                        
                        # Skip page title row (more robust detection)
                        if (len(row) >= 5 and 
                            row[5] and 
                            'Injury Repor' in row[5].strip()):
                            # print("  → Skipping title row") # For debugging
                            continue
                        
                        # Skip header row (2nd column is 'GameDate')
                        if len(row) >= 2 and row[1] and row[1].strip() == 'GameDate':
                            # print("  → Skipping header row") # For debugging
                            continue
                        
                        # Check if this is a date row (2nd column is date format)
                        if len(row) >= 2 and row[1] and row[1].strip():
                            # print("  → Found potential date row") # For debugging
                            # print(f"  Date string: {row[1].strip()}") # For debugging
                            try:
                                # Try both date formats
                                date_formats = ['%m/%d/%y', '%m/%d/%Y']
                                parsed_date = None
                                
                                for date_format in date_formats:
                                    try:
                                        parsed_date = datetime.strptime(row[1].strip(), date_format)
                                        # print(f"  ✓ Successfully parsed date: {parsed_date}") # For debugging
                                        break
                                    except ValueError:
                                        continue
                                
                                if parsed_date is None:
                                    print(f"  ✗ Failed to parse date with both formats") # Error note if date can't be parsed
                                    continue
                                
                                # Store the date row data
                                date_row_data = {
                                    'player_name': row[6] if len(row) >= 7 and row[6] else "",
                                    'current_status': row[7] if len(row) >= 8 and row[7] else "",
                                    'reason': row[8] if len(row) >= 9 and row[8] else ""
                                }
                                
                                # If we already encountered a date, stop processing
                                if date_encountered:
                                    print(f" Found next game date: {row[1]}")
                                    print(" Stopping processing as we've reached next date")
                                    return pd.DataFrame(data_list)
                                
                                date_encountered = True
                                game_date = parsed_date.strftime('%Y-%m-%d')
                                print(f" Set game date: {game_date}")
                                
                                # Only add date row if it contains player information
                                # AND we haven't added any rows yet
                                if date_row_data['player_name'] and not data_list:
                                    name_parts = split_name(date_row_data['player_name'])
                                    data_list.append({
                                        'Game Date': game_date,
                                        'Last Name': name_parts[0],
                                        'First Name': name_parts[1],
                                        'Current Status': date_row_data['current_status'],
                                        'Reason': date_row_data['reason']
                                    })
                            except ValueError:
                                print(f" Failed to parse date: {row[1].strip()}")
                                continue
                        
                        # Process player data rows
                        if len(row) >= 9 and row[6]:  # Check 7th column (index 6)
                            # Skip rows that don't have proper player data
                            if len(row) >= 8 and not row[7]:  # Skip if no status
                                # print("  → Skipping incomplete player data")
                                continue
                            
                            # Skip if this is the same as the date row
                            if date_row_data and row[6] == date_row_data['player_name']:
                                # print("  → Skipping duplicate date row entry")
                                continue
                            
                            player_name = row[6] if row[6] else ""
                            current_status = row[7] if row[7] else ""
                            reason = row[8] if row[8] else ""
                            
                            # Split name
                            name_parts = split_name(player_name)
                            
                            # Add row data to list
                            data_list.append({
                                'Game Date': game_date,
                                'Last Name': name_parts[0],
                                'First Name': name_parts[1],
                                'Current Status': current_status,
                                'Reason': reason
                            })
            
            # Convert list to DataFrame at the end
            if data_list:
                return pd.DataFrame(data_list)
            return pd.DataFrame()
    
    except Exception as e:
        print(f" Error parsing {pdf_url}: {str(e)}") # Error note if pdf_url is inaccessible
        return pd.DataFrame()     
        
def batch_parse_injury_reports(start_date, end_date):
    """
    Batch process multiple injury reports.
    
    Args:
        start_date (str): Start date in YYYY-MM-DD format
        end_date (str): End date in YYYY-MM-DD format
    
    Returns:
        pd.DataFrame: Concatenated DataFrame with all injury reports
    """
    urls = generate_injury_report_urls(start_date, end_date)
    all_dfs = []
    
    for url in urls:
        print(f"\n{'='*50}")
        df = parse_injury_pdf(url)
        if not df.empty:
            all_dfs.append(df)
    
    return pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()

# %%
# Example usage
start_date = "2025-02-19"
end_date = "2025-06-22"
df_injury_2024_25 = batch_parse_injury_reports(start_date, end_date)
print(df_injury_2024_25.head())
# Out:
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-02-19_10AM.pdf
#   ✓ Successfully parsed date: 2025-02-19 00:00:00
#   ✓ Successfully parsed date: 2025-02-20 00:00:00
# 📅 Found next game date: 02/20/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-02-20_10AM.pdf
#   ✓ Successfully parsed date: 2025-02-20 00:00:00
#   ✓ Successfully parsed date: 2025-02-21 00:00:00
# 📅 Found next game date: 02/21/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-02-21_10AM.pdf
#   ✓ Successfully parsed date: 2025-02-21 00:00:00
#   ✓ Successfully parsed date: 2025-02-22 00:00:00
# 📅 Found next game date: 02/22/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-02-22_10AM.pdf
#   ✓ Successfully parsed date: 2025-02-22 00:00:00
#   ✓ Successfully parsed date: 2025-02-23 00:00:00
# 📅 Found next game date: 02/23/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-02-23_10AM.pdf
#   ✓ Successfully parsed date: 2025-02-23 00:00:00
#   ✓ Successfully parsed date: 2025-02-24 00:00:00
# 📅 Found next game date: 02/24/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-02-24_10AM.pdf
#   ✓ Successfully parsed date: 2025-02-24 00:00:00
#   ✓ Successfully parsed date: 2025-02-25 00:00:00
# 📅 Found next game date: 02/25/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-02-25_10AM.pdf
#   ✓ Successfully parsed date: 2025-02-25 00:00:00
#   ✓ Successfully parsed date: 2025-02-26 00:00:00
# 📅 Found next game date: 02/26/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-02-26_10AM.pdf
#   ✓ Successfully parsed date: 2025-02-26 00:00:00
#   ✓ Successfully parsed date: 2025-02-27 00:00:00
# 📅 Found next game date: 02/27/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-02-27_10AM.pdf
#   ✓ Successfully parsed date: 2025-02-27 00:00:00
#   ✓ Successfully parsed date: 2025-02-28 00:00:00
# 📅 Found next game date: 02/28/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-02-28_10AM.pdf
#   ✓ Successfully parsed date: 2025-02-28 00:00:00
#   ✓ Successfully parsed date: 2025-03-01 00:00:00
# 📅 Found next game date: 03/01/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-01_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-01 00:00:00
#   ✓ Successfully parsed date: 2025-03-02 00:00:00
# 📅 Found next game date: 03/02/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-02_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-02 00:00:00
#   ✓ Successfully parsed date: 2025-03-03 00:00:00
# 📅 Found next game date: 03/03/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-03_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-03 00:00:00
#   ✓ Successfully parsed date: 2025-03-04 00:00:00
# 📅 Found next game date: 03/04/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-04_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-04 00:00:00
#   ✓ Successfully parsed date: 2025-03-05 00:00:00
# 📅 Found next game date: 03/05/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-05_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-05 00:00:00
#   ✓ Successfully parsed date: 2025-03-06 00:00:00
# 📅 Found next game date: 03/06/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-06_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-06 00:00:00
#   ✓ Successfully parsed date: 2025-03-07 00:00:00
# 📅 Found next game date: 03/07/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-07_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-07 00:00:00
#   ✓ Successfully parsed date: 2025-03-08 00:00:00
# 📅 Found next game date: 03/08/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-08_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-08 00:00:00
#   ✓ Successfully parsed date: 2025-03-09 00:00:00
# 📅 Found next game date: 03/09/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-09_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-09 00:00:00
#   ✓ Successfully parsed date: 2025-03-10 00:00:00
# 📅 Found next game date: 03/10/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-10_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-10 00:00:00
#   ✓ Successfully parsed date: 2025-03-11 00:00:00
# 📅 Found next game date: 03/11/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-11_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-11 00:00:00
#   ✓ Successfully parsed date: 2025-03-12 00:00:00
# 📅 Found next game date: 03/12/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-12_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-12 00:00:00
#   ✓ Successfully parsed date: 2025-03-13 00:00:00
# 📅 Found next game date: 03/13/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-13_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-13 00:00:00
#   ✓ Successfully parsed date: 2025-03-14 00:00:00
# 📅 Found next game date: 03/14/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-14_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-14 00:00:00
#   ✓ Successfully parsed date: 2025-03-15 00:00:00
# 📅 Found next game date: 03/15/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-15_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-15 00:00:00
#   ✓ Successfully parsed date: 2025-03-16 00:00:00
# 📅 Found next game date: 03/16/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-16_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-16 00:00:00
#   ✓ Successfully parsed date: 2025-03-17 00:00:00
# 📅 Found next game date: 03/17/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-17_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-17 00:00:00
#   ✓ Successfully parsed date: 2025-03-18 00:00:00
# 📅 Found next game date: 03/18/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-18_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-18 00:00:00
#   ✓ Successfully parsed date: 2025-03-19 00:00:00
# 📅 Found next game date: 03/19/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-19_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-19 00:00:00
#   ✓ Successfully parsed date: 2025-03-20 00:00:00
# 📅 Found next game date: 03/20/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-20_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-20 00:00:00
#   ✓ Successfully parsed date: 2025-03-21 00:00:00
# 📅 Found next game date: 03/21/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-21_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-21 00:00:00
#   ✓ Successfully parsed date: 2025-03-22 00:00:00
# 📅 Found next game date: 03/22/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-22_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-22 00:00:00
#   ✓ Successfully parsed date: 2025-03-23 00:00:00
# 📅 Found next game date: 03/23/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-23_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-23 00:00:00
#   ✓ Successfully parsed date: 2025-03-24 00:00:00
# 📅 Found next game date: 03/24/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-24_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-24 00:00:00
#   ✓ Successfully parsed date: 2025-03-25 00:00:00
# 📅 Found next game date: 03/25/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-25_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-25 00:00:00
#   ✓ Successfully parsed date: 2025-03-26 00:00:00
# 📅 Found next game date: 03/26/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-26_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-26 00:00:00
#   ✓ Successfully parsed date: 2025-03-27 00:00:00
# 📅 Found next game date: 03/27/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-27_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-27 00:00:00
#   ✓ Successfully parsed date: 2025-03-28 00:00:00
# 📅 Found next game date: 03/28/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-28_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-28 00:00:00
#   ✓ Successfully parsed date: 2025-03-29 00:00:00
# 📅 Found next game date: 03/29/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-29_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-29 00:00:00
#   ✓ Successfully parsed date: 2025-03-30 00:00:00
# 📅 Found next game date: 03/30/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-30_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-30 00:00:00
#   ✓ Successfully parsed date: 2025-03-31 00:00:00
# 📅 Found next game date: 03/31/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-03-31_10AM.pdf
#   ✓ Successfully parsed date: 2025-03-31 00:00:00
#   ✓ Successfully parsed date: 2025-04-01 00:00:00
# 📅 Found next game date: 04/01/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-01_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-01 00:00:00
#   ✓ Successfully parsed date: 2025-04-02 00:00:00
# 📅 Found next game date: 04/02/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-02_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-02 00:00:00
#   ✓ Successfully parsed date: 2025-04-03 00:00:00
# 📅 Found next game date: 04/03/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-03_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-03 00:00:00
#   ✓ Successfully parsed date: 2025-04-04 00:00:00
# 📅 Found next game date: 04/04/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-04_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-04 00:00:00
#   ✓ Successfully parsed date: 2025-04-05 00:00:00
# 📅 Found next game date: 04/05/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-05_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-05 00:00:00
#   ✓ Successfully parsed date: 2025-04-06 00:00:00
# 📅 Found next game date: 04/06/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-06_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-06 00:00:00
#   ✓ Successfully parsed date: 2025-04-07 00:00:00
# 📅 Found next game date: 04/07/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-07_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-07 00:00:00
#   ✓ Successfully parsed date: 2025-04-08 00:00:00
# 📅 Found next game date: 04/08/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-08_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-08 00:00:00
#   ✓ Successfully parsed date: 2025-04-09 00:00:00
# 📅 Found next game date: 04/09/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-09_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-09 00:00:00
#   ✓ Successfully parsed date: 2025-04-10 00:00:00
# 📅 Found next game date: 04/10/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-10_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-10 00:00:00
#   ✓ Successfully parsed date: 2025-04-11 00:00:00
# 📅 Found next game date: 04/11/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-11_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-11 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-12_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-13 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-13_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-13 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-14_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-15 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-15_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-15 00:00:00
#   ✓ Successfully parsed date: 2025-04-16 00:00:00
# 📅 Found next game date: 04/16/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-16_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-16 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-17_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-18 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-18_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-18 00:00:00
#   ✓ Successfully parsed date: 2025-04-19 00:00:00
# 📅 Found next game date: 04/19/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-19_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-19 00:00:00
#   ✓ Successfully parsed date: 2025-04-20 00:00:00
# 📅 Found next game date: 04/20/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-20_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-20 00:00:00
#   ✓ Successfully parsed date: 2025-04-21 00:00:00
# 📅 Found next game date: 04/21/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-21_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-21 00:00:00
#   ✓ Successfully parsed date: 2025-04-22 00:00:00
# 📅 Found next game date: 04/22/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-22_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-22 00:00:00
#   ✓ Successfully parsed date: 2025-04-23 00:00:00
# 📅 Found next game date: 04/23/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-23_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-23 00:00:00
#   ✓ Successfully parsed date: 2025-04-24 00:00:00
# 📅 Found next game date: 04/24/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-24_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-24 00:00:00
#   ✓ Successfully parsed date: 2025-04-25 00:00:00
# 📅 Found next game date: 04/25/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-25_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-25 00:00:00
#   ✓ Successfully parsed date: 2025-04-26 00:00:00
# 📅 Found next game date: 04/26/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-26_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-26 00:00:00
#   ✓ Successfully parsed date: 2025-04-27 00:00:00
# 📅 Found next game date: 04/27/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-27_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-27 00:00:00
#   ✓ Successfully parsed date: 2025-04-28 00:00:00
# 📅 Found next game date: 04/28/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-28_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-28 00:00:00
#   ✓ Successfully parsed date: 2025-04-29 00:00:00
# 📅 Found next game date: 04/29/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-29_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-29 00:00:00
#   ✓ Successfully parsed date: 2025-04-30 00:00:00
# 📅 Found next game date: 04/30/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-04-30_10AM.pdf
#   ✓ Successfully parsed date: 2025-04-30 00:00:00
#   ✓ Successfully parsed date: 2025-05-01 00:00:00
# 📅 Found next game date: 05/01/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-01_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-01 00:00:00
#   ✓ Successfully parsed date: 2025-05-02 00:00:00
# 📅 Found next game date: 05/02/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-02_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-02 00:00:00
#   ✓ Successfully parsed date: 2025-05-03 00:00:00
# 📅 Found next game date: 05/03/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-03_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-03 00:00:00
#   ✓ Successfully parsed date: 2025-05-04 00:00:00
# 📅 Found next game date: 05/04/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-04_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-04 00:00:00
#   ✓ Successfully parsed date: 2025-05-05 00:00:00
# 📅 Found next game date: 05/05/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-05_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-05 00:00:00
#   ✓ Successfully parsed date: 2025-05-06 00:00:00
# 📅 Found next game date: 05/06/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-06_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-06 00:00:00
#   ✓ Successfully parsed date: 2025-05-07 00:00:00
# 📅 Found next game date: 05/07/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-07_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-07 00:00:00
#   ✓ Successfully parsed date: 2025-05-08 00:00:00
# 📅 Found next game date: 05/08/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-08_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-08 00:00:00
#   ✓ Successfully parsed date: 2025-05-09 00:00:00
# 📅 Found next game date: 05/09/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-09_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-09 00:00:00
#   ✓ Successfully parsed date: 2025-05-10 00:00:00
# 📅 Found next game date: 05/10/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-10_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-10 00:00:00
#   ✓ Successfully parsed date: 2025-05-11 00:00:00
# 📅 Found next game date: 05/11/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-11_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-11 00:00:00
#   ✓ Successfully parsed date: 2025-05-12 00:00:00
# 📅 Found next game date: 05/12/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-12_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-12 00:00:00
#   ✓ Successfully parsed date: 2025-05-13 00:00:00
# 📅 Found next game date: 05/13/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-13_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-13 00:00:00
#   ✓ Successfully parsed date: 2025-05-14 00:00:00
# 📅 Found next game date: 05/14/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-14_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-14 00:00:00
#   ✓ Successfully parsed date: 2025-05-15 00:00:00
# 📅 Found next game date: 05/15/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-15_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-15 00:00:00
#   ✓ Successfully parsed date: 2025-05-16 00:00:00
# 📅 Found next game date: 05/16/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-16_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-16 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-17_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-18 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-18_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-18 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-19_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-20 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-20_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-20 00:00:00
#   ✓ Successfully parsed date: 2025-05-21 00:00:00
# 📅 Found next game date: 05/21/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-21_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-21 00:00:00
#   ✓ Successfully parsed date: 2025-05-22 00:00:00
# 📅 Found next game date: 05/22/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-22_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-22 00:00:00
#   ✓ Successfully parsed date: 2025-05-23 00:00:00
# 📅 Found next game date: 05/23/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-23_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-23 00:00:00
#   ✓ Successfully parsed date: 2025-05-24 00:00:00
# 📅 Found next game date: 05/24/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-24_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-24 00:00:00
#   ✓ Successfully parsed date: 2025-05-25 00:00:00
# 📅 Found next game date: 05/25/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-25_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-25 00:00:00
#   ✓ Successfully parsed date: 2025-05-26 00:00:00
# 📅 Found next game date: 05/26/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-26_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-26 00:00:00
#   ✓ Successfully parsed date: 2025-05-27 00:00:00
# 📅 Found next game date: 05/27/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-27_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-27 00:00:00
#   ✓ Successfully parsed date: 2025-05-28 00:00:00
# 📅 Found next game date: 05/28/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-28_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-28 00:00:00
#   ✓ Successfully parsed date: 2025-05-29 00:00:00
# 📅 Found next game date: 05/29/2025
# 👋 Stopping processing as we've reached next game
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-29_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-29 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-30_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-31 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-05-31_10AM.pdf
#   ✓ Successfully parsed date: 2025-05-31 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-01_10AM.pdf
# ❌ Failed to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-01_10AM.pdf
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-02_10AM.pdf
# ❌ Failed to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-02_10AM.pdf
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-03_10AM.pdf
# ❌ Failed to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-03_10AM.pdf
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-04_10AM.pdf
#   ✓ Successfully parsed date: 2025-06-05 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-05_10AM.pdf
#   ✓ Successfully parsed date: 2025-06-05 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-06_10AM.pdf
# ❌ Failed to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-06_10AM.pdf
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-07_10AM.pdf
#   ✓ Successfully parsed date: 2025-06-08 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-08_10AM.pdf
#   ✓ Successfully parsed date: 2025-06-08 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-09_10AM.pdf
# ❌ Failed to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-09_10AM.pdf
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-10_10AM.pdf
#   ✓ Successfully parsed date: 2025-06-11 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-11_10AM.pdf
#   ✓ Successfully parsed date: 2025-06-11 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-12_10AM.pdf
#   ✓ Successfully parsed date: 2025-06-13 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-13_10AM.pdf
#   ✓ Successfully parsed date: 2025-06-13 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-14_10AM.pdf
# ❌ Failed to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-14_10AM.pdf
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-15_10AM.pdf
#   ✓ Successfully parsed date: 2025-06-16 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-16_10AM.pdf
#   ✓ Successfully parsed date: 2025-06-16 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-17_10AM.pdf
# ❌ Failed to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-17_10AM.pdf
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-18_10AM.pdf
#   ✓ Successfully parsed date: 2025-06-19 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-19_10AM.pdf
#   ✓ Successfully parsed date: 2025-06-19 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-20_10AM.pdf
# ❌ Failed to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-20_10AM.pdf
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-21_10AM.pdf
#   ✓ Successfully parsed date: 2025-06-22 00:00:00
#
# ==================================================
# 🔍 Attempting to fetch: https://ak-static.cms.nba.com/referee/injury/Injury-Report_2025-06-22_10AM.pdf
#   ✓ Successfully parsed date: 2025-06-22 00:00:00
#     Game Date Last Name First Name Current Status  \
# 0  2025-02-19      Ball     LaMelo       Probable
# 1  2025-02-19      Mann        Tre            Out
# 2  2025-02-19    Miller    Brandon            Out
# 3  2025-02-19    Okogie       Josh            Out
# 4  2025-02-19  Williams      Grant            Out
#
#                                        Reason
# 0          Injury/Illness-RightAnkle;Soreness
# 1              Injury/Illness-Disc;Herniation
# 2  Injury/Illness-RightWrist;Ligament\nRepair
# 3         Injury/Illness-LeftHamstring;Strain
# 4              Injury/Illness-RightACL;Repair

# %%
df_injury_2024_25.shape
# Out:
# (4208, 5)

# %%
df_injury_2024_25.head(10)
# Out:
#     Game Date Last Name First Name Current Status  \
# 0  2025-02-19      Ball     LaMelo       Probable
# 1  2025-02-19      Mann        Tre            Out
# 2  2025-02-19    Miller    Brandon            Out
# 3  2025-02-19    Okogie       Josh            Out
# 4  2025-02-19  Williams      Grant            Out
# 5  2025-02-19  Williams       Mark       Probable
# 6  2025-02-19     James     LeBron   Questionable
# 7  2025-02-19    Kleber       Maxi            Out
# 8  2025-02-20   Davison         JD            Out
# 9  2025-02-20  Peterson       Drew            Out
#
#                                        Reason
# 0          Injury/Illness-RightAnkle;Soreness
# 1              Injury/Illness-Disc;Herniation
# 2  Injury/Illness-RightWrist;Ligament\nRepair
# 3         Injury/Illness-LeftHamstring;Strain
# 4              Injury/Illness-RightACL;Repair
# 5         ReturntoCompetition\nReconditioning
# 6            Injury/Illness-LeftFoot;Soreness
# 7  Injury/Illness-RightFoot;Surgery\nRecovery
# 8                             GLeague-Two-Way
# 9                             GLeague-Two-Way

# %%
df_injury_24_25 = df_injury_2024_25.copy()

# %%
df_injury_24_25.to_excel("NBA_Injury_Report_2024_25.xlsx", index=False)

# %%
df_injury_24_25 = pd.concat([df_injury_24_25,df_injury_2024_25],ignore_index=True)

# %%
df_injury_24_25.shape
# Out:
# (11173, 5)

# %% [markdown]
# ## Revised code next to extract NBA 2022-23 season due to subtle format change in 2024-25 season leading to a different table extraction module

# %% [markdown]
# ## This code is for 2022-23 season until May 2nd, 2023
# ### Notes: From beginning of 22-23 season, the format followed was old one till May 2nd, 2023
# ### From May 3rd, 2023, The new format was adopted which is valid thru 24-25.

# %%
import pandas as pd
import requests
from io import BytesIO
import pdfplumber
from datetime import datetime, timedelta
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

def generate_injury_report_urls(start_date, end_date):
    """
    Generate URLs for injury reports between specified dates.
    
    Args:
        start_date (str): Start date in YYYY-MM-DD format
        end_date (str): End date in YYYY-MM-DD format
    
    Returns:
        list: List of URLs for injury reports
    """
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    urls = []
    while start <= end:
        date_str = start.strftime("%Y-%m-%d")
        url = f"https://ak-static.cms.nba.com/referee/injury/Injury-Report_{date_str}_10AM.pdf"
        urls.append(url)
        start += timedelta(days=1)
    return urls
    
def split_name(full_name):
    """
    Split a full name into last name and first name.
    Handles common name formats like "Last, First" and "First Last"
    """
    if not full_name:
        return ["", ""]
    
    # Handle "Last, First" format
    if ',' in full_name:
        parts = full_name.split(',')
        return [parts[0].strip(), parts[1].strip()]
    
    # Handle "First Last" format
    parts = full_name.split()
    if len(parts) >= 2:
        return [parts[-1], ' '.join(parts[:-1])]
    
    # If we can't split the name, return it as last name
    return [full_name, ""]
    
def parse_injury_pdf(pdf_url, game_date=None):
    try:
        print(f"Attempting to fetch: {pdf_url}")
        
        # Setup retry strategy for requests
        session = requests.Session()
        retry_strategy = Retry(
            total=3,
            backoff_factor=1,
            status_forcelist=[429, 500, 502, 503, 504]
        )
        adapter = HTTPAdapter(max_retries=retry_strategy)
        session.mount("http://", adapter)
        session.mount("https://", adapter)
        
        response = session.get(pdf_url, timeout=30)
        if response.status_code != 200:
            print(f"Failed to fetch: {pdf_url}") 
            return pd.DataFrame()
            
        with pdfplumber.open(BytesIO(response.content)) as pdf:
            data_list = []
            date_encountered = False
            date_row_data = None
            
            for page in pdf.pages:
                tables = page.find_tables({
                    "vertical_strategy": "explicit",
                    "horizontal_strategy": "explicit",
                    "explicit_vertical_lines": [edge["x0"] for edge in page.edges],
                    "explicit_horizontal_lines": [edge["top"] for edge in page.edges],
                    "snap_tolerance": 5,
                    "join_tolerance": 5
                })
                
                print(f" Found {len(tables)} tables on page") # For debugging
                
                for table in tables:
                    table_data = table.extract()
                    print(f"Table shape: {len(table_data)} rows") # For debugging
                    
                    for i, row in enumerate(table_data):
                        print(f" Row {i} contents:") # For debugging
                        print(f" Length: {len(row)}") # For debugging
                        print(f" Row data: {row}") # For debugging
                        
                        # Skip empty rows
                        if not any(row):
                            print("  → Skipping empty row")
                            continue
                        
                        # Skip page title row (more robust detection) - Not relevant for 22-23 season
                        #if (len(row) >= 5 and 
                           # row[5] and 
                           # 'Injury Repor' in row[5].strip()):
                           # print("  → Skipping title row") # For debugging
                           # continue
                        
                        # Skip header row (2nd column is 'GameDate')
                        if len(row) >= 2 and row[2] and row[2].strip() == 'Game':
                            print("  → Skipping header row") # For debugging
                            continue
                        
                        # Check if this is a date row (2nd column is date format)
                        if len(row) >= 2 and row[2] and row[2].strip():
                            print("  → Found potential date row") # For debugging
                            print(f"  Date string: {row[2].strip()+row[3].strip()}") # For debugging
                            try:
                                # Try both date formats
                                date_formats = ['%m/%d/%y', '%m/%d/%Y']
                                parsed_date = None
                                
                                for date_format in date_formats:
                                    try:
                                        string_date = row[2].strip()+row[3].strip()
                                        parsed_date = datetime.strptime(string_date, date_format)
                                        # print(f"  ✓ Successfully parsed date: {parsed_date}") # For debugging
                                        break
                                    except ValueError:
                                        continue
                                
                                if parsed_date is None:
                                    print(f"  ✗ Failed to parse date with both formats") # Error note if date can't be parsed
                                    continue
                                
                                # Store the date row data
                                date_row_data = {
                                    'player_name': row[7] if len(row) >= 7 and row[7] else "",
                                    'current_status': row[8] if len(row) >= 8 and row[8] else "",
                                    'reason': row[9] if len(row) >= 9 and row[9] else ""
                                }
                                
                                # If we already encountered a date, stop processing
                                if date_encountered:
                                    print(f" Found next game date: {row[2]+row[3]}")
                                    print(" Stopping processing as we've reached next date")
                                    return pd.DataFrame(data_list)
                                
                                date_encountered = True
                                game_date = parsed_date.strftime('%Y-%m-%d')
                                print(f" Set game date: {game_date}")
                                
                                # Only add date row if it contains player information
                                # AND we haven't added any rows yet
                                if date_row_data['player_name'] and not data_list:
                                    name_parts = split_name(date_row_data['player_name'])
                                    data_list.append({
                                        'Game Date': game_date,
                                        'Last Name': name_parts[0],
                                        'First Name': name_parts[1],
                                        'Current Status': date_row_data['current_status'],
                                        'Reason': date_row_data['reason']
                                    })
                            except ValueError:
                                print(f" Failed to parse date: {row[2].strip()}")
                                continue
                        
                        # Process player data rows
                        if len(row) >= 9 and row[7]:  # Check 8th column (index 7)
                            # Skip rows that don't have proper player data
                            if len(row) >= 8 and not row[8]:  # Skip if no status
                                print("  → Skipping incomplete player data")
                                continue
                            
                            # Skip if this is the same as the date row
                            if date_row_data and row[7] == date_row_data['player_name']:
                                print("  → Skipping duplicate date row entry")
                                continue
                            
                            player_name = row[7] if row[7] else ""
                            current_status = row[8] if row[8] else ""
                            reason = row[9] if row[9] else ""
                            
                            # Split name
                            name_parts = split_name(player_name)
                            
                            # Add row data to list
                            data_list.append({
                                'Game Date': game_date,
                                'Last Name': name_parts[0],
                                'First Name': name_parts[1],
                                'Current Status': current_status,
                                'Reason': reason
                            })
            
            # Convert list to DataFrame at the end
            if data_list:
                return pd.DataFrame(data_list)
            return pd.DataFrame()
    
    except Exception as e:
        print(f" Error parsing {pdf_url}: {str(e)}") # Error note if pdf_url is inaccessible
        return pd.DataFrame()     
        
def batch_parse_injury_reports(start_date, end_date):
    """
    Batch process multiple injury reports.
    
    Args:
        start_date (str): Start date in YYYY-MM-DD format
        end_date (str): End date in YYYY-MM-DD format
    
    Returns:
        pd.DataFrame: Concatenated DataFrame with all injury reports
    """
    urls = generate_injury_report_urls(start_date, end_date)
    all_dfs = []
    
    for url in urls:
        print(f"\n{'='*50}")
        df = parse_injury_pdf(url)
        if not df.empty:
            all_dfs.append(df)
    
    return pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()

# %%
df_injury_2022_23.shape
# Out:
# (175, 5)

# %%
df_injury_22_23 = df_injury_2022_23.copy()

# %%
df_injury_22_23 = pd.concat([df_injury_22_23,df_injury_2022_23],ignore_index=True)

# %%
df_injury_22_23.shape
# Out:
# (9281, 5)

# %%
df_injury_22_23.tail()
# Out:
#        Game Date Last Name First Name Current Status  \
# 9276  2023-06-12   Adebayo        Bam      Available
# 9277  2023-06-12     Herro      Tyler            Out
# 9278  2023-06-12   Oladipo     Victor            Out
# 9279  2023-06-12   Vincent       Gabe      Available
# 9280  2023-06-12    Zeller       Cody      Available
#
#                                          Reason
# 9276  Injury/Illness-RightShoulder;\nDiscomfort
# 9277           Injury/Illness-RightHand;Surgery
# 9278            Injury/Illness-LeftKnee;Surgery
# 9279          Injury/Illness-LeftAnkle;Soreness
# 9280              Injury/Illness-Nasal;Fracture

# %%
df_injury_22_23.to_excel("NBA_Injury_Report_2022_23.xlsx", index=False)
